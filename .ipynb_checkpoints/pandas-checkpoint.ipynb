# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#  df.head()
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df = pd.read_csv("titanic.csv",nrows=10)
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df = pd.read_csv("titanic.csv",sep=',')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
s = df[['PassengerId', 'Name', 'Age', 'Sex']]
s.head()
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#       Sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %%
# making data frame from csv file
data = pd.read_csv("titanic.csv", index_col ="Name")
 
# retrieving row by loc method
first = data.loc["Braund, Mr. Owen Harris"]
second = data.loc["Heikkinen, Miss. Laina"]
 
 
print(first, "\n\n\n", second)
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object
#
#
#  PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                        26.0
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df = pd.read_csv("titanic.csv", header=None)
df.head()
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
# retrieving columns by indexing operator
data = pd.read_csv("titanic.csv", index_col ="Ticket")
first = data["Age"]
# second = data["Sex"]
first.head()
# second.head()
# Out:
# Ticket
# A/5 21171           22.0
# PC 17599            38.0
# STON/O2. 3101282    26.0
# 113803              35.0
# 373450              35.0
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
# retrieving rows by iloc method 
row2 = data.iloc[3]
row2.head()
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Name: 113803, dtype: object

# %%
# using isnull() function  
# df.isnull()
# df.notnull()

# %%
# filling missing value using fillna()  
# df.fillna(0)

# %%
# drop rows with at least one Nan value (Null value)
df.head()
drop = df.dropna()
drop.head()
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 2             2         1       1
# 4             4         1       1
# 7             7         0       1
# 11           11         1       3
#
#                                                    3       4    5      6   \
# 0                                                Name     Sex  Age  SibSp
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 4        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 7                             McCarthy, Mr. Timothy J    male   54      0
# 11                    Sandstrom, Miss. Marguerite Rut  female    4      1
#
#        7         8        9      10        11
# 0   Parch    Ticket     Fare  Cabin  Embarked
# 2       0  PC 17599  71.2833    C85         C
# 4       0    113803     53.1   C123         S
# 7       0     17463  51.8625    E46         S
# 11      1   PP 9549     16.7     G6         S

# %%
# iterating over rows using iterrows() function 
df_row = df.head()
for i, j in df_row.iterrows():
    print(i, j)
    print()
# Out:
# 0 0     PassengerId
# 1        Survived
# 2          Pclass
# 3            Name
# 4             Sex
# 5             Age
# 6           SibSp
# 7           Parch
# 8          Ticket
# 9            Fare
# 10          Cabin
# 11       Embarked
# Name: 0, dtype: object
#
# 1 0                           1
# 1                           0
# 2                           3
# 3     Braund, Mr. Owen Harris
# 4                        male
# 5                          22
# 6                           1
# 7                           0
# 8                   A/5 21171
# 9                        7.25
# 10                        NaN
# 11                          S
# Name: 1, dtype: object
#
# 2 0                                                     2
# 1                                                     1
# 2                                                     1
# 3     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 4                                                female
# ...

# %%
df_col = list(df)
for i in df_col:
    print(df[i][2])
# Out:
# 2
# 1
# 1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# female
# 38
# 1
# 0
# PC 17599
# 71.2833
# C85
# C

# %%
# Indexing a Series using indexing operator []
ser = pd.Series(['Name']) 
data = ser.head(10)
data
# Out:
# 0    Name
# dtype: object

# %%
# using indexing operator
data[3:6]
# Out:
# Series([], dtype: object)

# %%
# using .iloc[] function
data.iloc[3:6]
# Out:
# Series([], dtype: object)

# %%
data.loc[3:6]
# Out:
# Series([], dtype: object)

# %%
data2 = pd.read_csv('nba.csv')
data2.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
# age = df[df['Age'] == 22]
# age[['Name', 'Age']]

# df['Age'].unique()

# lst = list(df['Age'])
# lst

# %%
# list(set(lst))

# %%
male = age[age['Sex'] == 'male']
male.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 75            76         0       3
# 134          135         0       2
# 267          268         1       3
# 271          272         1       3
# 343          344         0       2
# 353          354         0       3
# 370          371         1       1
# 442          443         0       3
# 484          485         1       1
# 666          667         0       2
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 75                      Moen, Mr. Sigurd Hansen  male  25.0      0      0
# 134              Sobey, Mr. Samuel James Hayden  male  25.0      0      0
# 267                    Persson, Mr. Ernst Ulrik  male  25.0      1      0
# 271                Tornquist, Mr. William Henry  male  25.0      0      0
# 343  Sedgwick, Mr. Charles Frederick Waddington  male  25.0      0      0
# 353                   Arnold-Franchi, Mr. Josef  male  25.0      1      0
# ...

# %%
df.shape 
# 891 rows and 12 columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sex = df['Sex']
sx = sex.head()
print(sx)
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
age2 = df[df['Age'] <= 60]
male = age2[age2['Sex'] == 'male']
male.head(10)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
# 16           17         0       3            Rice, Master. Eugene  male   2.0
# 20           21         0       2            Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2           Beesley, Mr. Lawrence  male  34.0
# 23           24         1       1    Sloper, Mr. William Thompson  male  28.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# ...

# %%
mix = df[(df['Age'] >= 25) & (df['Age'] <= 60) & (df['Sex'] == 'male')]
mix.head(10)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2            Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2           Beesley, Mr. Lawrence  male  34.0
# 23           24         1       1    Sloper, Mr. William Thompson  male  28.0
# 30           31         0       1        Uruchurtu, Don. Manuel E  male  40.0
# 34           35         0       1         Meyer, Mr. Edgar Joseph  male  28.0
# 35           36         0       1  Holverson, Mr. Alexander Oskar  male  42.0
# 57           58         0       3             Novel, Mr. Mansouer  male  28.5
#
#     SibSp  Parch    Ticket     Fare Cabin Embarked
# 4       0      0    373450   8.0500   NaN        S
# ...

# %%
s = df[['PassengerId', 'Name', 'Age', 'Sex', 'Ticket', 'Pclass']]
mix = s[(s['Age'] >= 25) & (s['Age'] <= 60) & (s['Sex'] == 'male')]
mix.head(10)

# mix['Age'].mean()
# mix.Age.mean()

# mix.sort_values(by='Age').head(30)

# j = df[df.isnull().values.any(axis = 1)]
# j.head(10)

# df['Condition'] = df['Age'].apply(lambda x:'true' if x >= 35 else 'false')
# df.head()
# Out:
#     PassengerId                            Name   Age   Sex    Ticket  Pclass
# 4             5        Allen, Mr. William Henry  35.0  male    373450       3
# 6             7         McCarthy, Mr. Timothy J  54.0  male     17463       1
# 13           14     Andersson, Mr. Anders Johan  39.0  male    347082       3
# 20           21            Fynney, Mr. Joseph J  35.0  male    239865       2
# 21           22           Beesley, Mr. Lawrence  34.0  male    248698       2
# 23           24    Sloper, Mr. William Thompson  28.0  male    113788       1
# 30           31        Uruchurtu, Don. Manuel E  40.0  male  PC 17601       1
# 34           35         Meyer, Mr. Edgar Joseph  28.0  male  PC 17604       1
# 35           36  Holverson, Mr. Alexander Oskar  42.0  male    113789       1
# 57           58             Novel, Mr. Mansouer  28.5  male      2697       3

# %%
#extract all the column names as a list
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# shows numerical values
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include= 'all')
# Out:
#         PassengerId    Survived      Pclass                         Name  \
# count    891.000000  891.000000  891.000000                          891
# unique          NaN         NaN         NaN                          891
# top             NaN         NaN         NaN  Thayer, Mr. John Borland Jr
# freq            NaN         NaN         NaN                            1
# mean     446.000000    0.383838    2.308642                          NaN
# std      257.353842    0.486592    0.836071                          NaN
# min        1.000000    0.000000    1.000000                          NaN
# 25%      223.500000    0.000000    2.000000                          NaN
# 50%      446.000000    0.000000    3.000000                          NaN
# 75%      668.500000    1.000000    3.000000                          NaN
# max      891.000000    1.000000    3.000000                          NaN
#
#          Sex         Age       SibSp       Parch  Ticket        Fare    Cabin  \
# ...

# %%
df.describe(include = ['object'])
# Out:
#                                Name   Sex  Ticket    Cabin Embarked
# count                           891   891     891      204      889
# unique                          891     2     681      147        3
# top     Thayer, Mr. John Borland Jr  male  347082  B96 B98        S
# freq                              1   577       7        4      644

# %%
df.describe(include = ['object', 'float'])
# Out:
#                                Name   Sex         Age  Ticket        Fare  \
# count                           891   891  714.000000     891  891.000000
# unique                          891     2         NaN     681         NaN
# top     Thayer, Mr. John Borland Jr  male         NaN  347082         NaN
# freq                              1   577         NaN       7         NaN
# mean                            NaN   NaN   29.699118     NaN   32.204208
# std                             NaN   NaN   14.526497     NaN   49.693429
# min                             NaN   NaN    0.420000     NaN    0.000000
# 25%                             NaN   NaN   20.125000     NaN    7.910400
# 50%                             NaN   NaN   28.000000     NaN   14.454200
# 75%                             NaN   NaN   38.000000     NaN   31.000000
# max                             NaN   NaN   80.000000     NaN  512.329200
#
#           Cabin Embarked
# count       204      889
# unique      147        3
# ...

# %%
# Specific type of Values
df[df['Sex'] == 'male'].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   577.000000  577.000000  577.000000  453.000000  577.000000
# mean    454.147314    0.188908    2.389948   30.726645    0.429809
# std     257.486139    0.391775    0.813580   14.678201    1.061811
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.000000    0.000000    2.000000   21.000000    0.000000
# 50%     464.000000    0.000000    3.000000   29.000000    0.000000
# 75%     680.000000    0.000000    3.000000   39.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  577.000000  577.000000
# mean     0.235702   25.523893
# std      0.612294   43.138263
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   10.500000
# 75%      0.000000   26.550000
# max      5.000000  512.329200

# %%
s = df[['PassengerId', 'Name', 'Age', 'Sex', 'Ticket', 'Pclass', 'Embarked']]
mix = s[((s['Embarked'] == 'S') & (s['Pclass'] == 3)) | (s['Age'] >= 25)]
mix.head(10)
# Out:
#     PassengerId                                               Name   Age  \
# 0             1                            Braund, Mr. Owen Harris  22.0
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2             3                             Heikkinen, Miss. Laina  26.0
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4             5                           Allen, Mr. William Henry  35.0
# 6             7                            McCarthy, Mr. Timothy J  54.0
# 7             8                     Palsson, Master. Gosta Leonard   2.0
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10           11                    Sandstrom, Miss. Marguerite Rut   4.0
# 11           12                           Bonnell, Miss. Elizabeth  58.0
#
#        Sex            Ticket  Pclass Embarked
# 0     male         A/5 21171       3        S
# 1   female          PC 17599       1        C
# ...
